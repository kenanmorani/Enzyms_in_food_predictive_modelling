# %% [markdown]
# <a href="https://colab.research.google.com/github/kenanmorani/Enzyms_in_food_predictive_modelling/blob/main/linear_regression_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * This model project is conducted for the purpose of fiting a model to help predict types of anzymes to be added and best waiting time required.
# At Yildiz Technical University

# %%
import numpy as np
from sklearn import linear_model
import pandas as pd
from sklearn.metrics import mean_squared_error, r2_score

# %%
import matplotlib.pyplot as plt

# %%
! git clone https://github.com/kenanmorani/Enzyms_in_food_predictive_modelling
# Out:
# Cloning into 'Enzyms_in_food_predictive_modelling'...
# remote: Enumerating objects: 45, done.
# remote: Counting objects: 100% (45/45), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 45 (delta 9), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (45/45), done.

# %%
dataset = pd.read_csv('/content/Enzyms_in_food_predictive_modelling/data/Farinograph Final Results.csv')

# %%
dataset.head()
# Out:
#    Novamyl 1500MG  Lipopan FBG  ...  Maximum(BU)  Ratio Number
# 0            35.0          4.0  ...        512.0            2.2
# 1            75.0          4.0  ...        429.0            1.6
# 2            35.0         10.0  ...        456.0            2.0
# 3            75.0         10.0  ...        512.0            2.1
# 4            75.0          4.0  ...        480.0            1.8
#
# [5 rows x 10 columns]

# %% [markdown]
# Preprocessing the data

# %%
# Deleting 'Time periods in minutes' coloumn
del dataset['Time Period in minutes']

# %%
dataset
# Out:
#      Novamyl 1500MG  Lipopan FBG  ...  Maximum(BU)  Ratio Number
# 0              35.0          4.0  ...        512.0            2.2
# 1              75.0          4.0  ...        429.0            1.6
# 2              35.0         10.0  ...        456.0            2.0
# 3              75.0         10.0  ...        512.0            2.1
# 4              75.0          4.0  ...        480.0            1.8
# ..              ...          ...  ...          ...            ...
# 974             NaN          NaN  ...          NaN            NaN
# 975             NaN          NaN  ...          NaN            NaN
# 976             NaN          NaN  ...          NaN            NaN
# 977             NaN          NaN  ...          NaN            NaN
# 978             NaN          NaN  ...          NaN            NaN
#
# [979 rows x 9 columns]

# %%
dataset = dataset.dropna()

# %%
dataset
# Out:
#     Novamyl 1500MG  Lipopan FBG  ...  Maximum(BU)  Ratio Number
# 0          35.0000       4.0000  ...        512.0            2.2
# 1          75.0000       4.0000  ...        429.0            1.6
# 2          35.0000      10.0000  ...        456.0            2.0
# 3          75.0000      10.0000  ...        512.0            2.1
# 4          75.0000       4.0000  ...        480.0            1.8
# 5          35.0000      10.0000  ...        400.0            1.7
# 6          75.0000      10.0000  ...        394.0            1.8
# 7          21.3641       7.0000  ...        399.0            1.8
# 8          88.6359       7.0000  ...        430.0            1.6
# 9          55.0000       1.9546  ...        456.0            1.8
# 10         55.0000      12.0454  ...        498.0            2.4
# 11         55.0000       7.0000  ...        498.0            2.4
# 12         55.0000       7.0000  ...        393.0            1.5
# ...

# %%
dataset.head()
# Out:
#    Novamyl 1500MG  Lipopan FBG  ...  Maximum(BU)  Ratio Number
# 0            35.0          4.0  ...        512.0            2.2
# 1            75.0          4.0  ...        429.0            1.6
# 2            35.0         10.0  ...        456.0            2.0
# 3            75.0         10.0  ...        512.0            2.1
# 4            75.0          4.0  ...        480.0            1.8
#
# [5 rows x 9 columns]

# %%
# The input (Time peiod & enzyms types)
x=dataset.iloc[:,0:4].values

# %%
x
# Out:
# array([[ 35.    ,   4.    ,  30.    ,   0.    ],
#        [ 75.    ,   4.    ,  30.    ,   0.    ],
#        [ 35.    ,  10.    ,  30.    ,   0.    ],
#        [ 75.    ,  10.    ,  30.    ,   0.    ],
#        [ 75.    ,   4.    , 100.    ,   0.    ],
#        [ 35.    ,  10.    , 100.    ,   0.    ],
#        [ 75.    ,  10.    , 100.    ,   0.    ],
#        [ 21.3641,   7.    ,  65.    ,   0.    ],
#        [ 88.6359,   7.    ,  65.    ,   0.    ],
#        [ 55.    ,   1.9546,  65.    ,   0.    ],
#        [ 55.    ,  12.0454,  65.    ,   0.    ],
#        [ 55.    ,   7.    ,   6.137 ,   0.    ],
#        [ 55.    ,   7.    , 123.863 ,   0.    ],
#        [ 55.    ,   7.    ,  65.    ,   0.    ],
#        [ 55.    ,   7.    ,  65.    ,   0.    ],
#        [ 35.    ,   4.    ,  30.    ,   1.    ],
#        [ 75.    ,   4.    ,  30.    ,   1.    ],
#        [ 35.    ,  10.    ,  30.    ,   1.    ],
#        [ 75.    ,  10.    ,  30.    ,   1.    ],
# ...

# %%
# The outputs (Energy & Resistance)
energy=dataset.iloc[:,4:5].values
resistance=dataset.iloc[:,5:6].values

# %%
print(X_Train.shape)
# Out:
# (30, 9)

# %%
print(Y_Train.shape)
# Out:
# (30, 1)

# %%
# Reshaping array to cvonvert from 1D to 2D
X_Train=X_Train.reshape(-1,1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-2e6bafa07c5e> in <module>()
#       1 # Reshaping array to cvonvert from 1D to 2D
# ----> 2 X_Train=X_Train.reshape(-1,1)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5139             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5140                 return self[name]
# -> 5141             return object.__getattribute__(self, name)
#    5142
#    5143     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'reshape'

# %%
# Splitting the dataset into the taining and test sets
from sklearn.model_selection import train_test_split
X_Train, X_Test, Y_Train, Y_Test = train_test_split(dataset, energy, test_size = 1/3, random_state = 0)

# %%
#lin_reg=linear_model.LinearRegression()
# Fitting Simple Linear Regression to the training set
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X_Train, Y_Train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# The mean square error
print("Coefficients:\n",lin_reg.coef_)
print("intercept:\n", lin_reg.intercept_)
# Out:
# Coefficients:
#  [[ 1.32732483e-16  1.09634524e-15  1.47451495e-16  9.40226223e-15
#    1.00000000e+00 -2.42861287e-16 -7.07767178e-16 -3.46944695e-17
#    1.74621602e-15]]
# intercept:
#  [1.13686838e-13]

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(Y_Test, Y_Pred))
print('Mean Squared Error:', metrics.mean_squared_error(Y_Test, Y_Pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(Y_Test, Y_Pred)))
# Out:
# Mean Absolute Error: 1.5158245029548804e-14
# Mean Squared Error: 3.769703312416142e-28
# Root Mean Squared Error: 1.9415723814517298e-14

# %% [markdown]
# The lin_reg model perfictly fit the data
